# %%
import logging
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data as mnist_input_data

import cnn_utils

# %%
# Setup logging.
reload(logging)
logging.basicConfig(format = "[%(asctime)s] %(message)s",
                    datefmt = "%Y-%m-%d %H:%M:%S",
                    level = logging.INFO)

# Create an interactive session.
sess = tf.InteractiveSession()

# %%
# Load the dataset.
dataset = mnist_input_data.read_data_sets("MNIST_data", one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
"""Define the network."""

# Input and output placeholders.
x = tf.placeholder(tf.float32, shape=[None, 784])
y_ = tf.placeholder(tf.float32, shape=[None, 10])

# Build the network.
keep_prob = tf.placeholder(tf.float32)
y = cnn_utils.inference(x, keep_prob)
loss = cnn_utils.loss(y, y_)
accuracy = cnn_utils.accuracy(y, y_)

# Setup training.
optimizer = tf.train.AdamOptimizer(1e-4)
train_step = cnn_utils.training(loss, accuracy, optimizer)
saver = tf.train.Saver()

summary = tf.merge_all_summaries()
summary_writer = tf.train.SummaryWriter("checkpoint", sess.graph)

# Save the graph.
tf.train.write_graph(sess.graph_def, "checkpoint", "graph.pb", as_text=True)

# %%
# Perform the training.
sess.run(tf.initialize_all_variables())
validation_feed_dict = {
    x:dataset.validation.images,
    y_: dataset.validation.labels,
    keep_prob: 1.0
}
for i in range(20000):
    batch = dataset.train.next_batch(50)
    sess.run(train_step, feed_dict={x: batch[0], y_: batch[1], keep_prob: 0.5})
    if (i+1) % 100 == 0:
        validation_accuracy = accuracy.eval(feed_dict=validation_feed_dict)
        logging.info("step %d, validation accuracy %.2f%%" %
                     (i+1, validation_accuracy * 100))
        saver.save(sess, "checkpoint/cnn", global_step = i+1)
        
        summary_str = sess.run(summary, feed_dict=validation_feed_dict)
        summary_writer.add_summary(summary_str, i+1)
        summary_writer.flush()
# Out:
# [2016-09-01 22:06:13] step 100, validation accuracy 83.68%
# [2016-09-01 22:06:17] step 200, validation accuracy 91.20%
# [2016-09-01 22:06:20] step 300, validation accuracy 92.98%
# [2016-09-01 22:06:23] step 400, validation accuracy 94.20%
# [2016-09-01 22:06:25] step 500, validation accuracy 94.36%
# [2016-09-01 22:06:28] step 600, validation accuracy 95.26%
# [2016-09-01 22:06:31] step 700, validation accuracy 95.52%
# [2016-09-01 22:06:34] step 800, validation accuracy 96.04%
# [2016-09-01 22:06:37] step 900, validation accuracy 96.00%
# [2016-09-01 22:06:40] step 1000, validation accuracy 96.48%
# [2016-09-01 22:06:43] step 1100, validation accuracy 96.36%
# [2016-09-01 22:06:45] step 1200, validation accuracy 96.76%
# [2016-09-01 22:06:48] step 1300, validation accuracy 97.06%
# [2016-09-01 22:06:51] step 1400, validation accuracy 97.10%
# [2016-09-01 22:06:54] step 1500, validation accuracy 97.04%
# [2016-09-01 22:06:57] step 1600, validation accuracy 97.18%
# [2016-09-01 22:07:00] step 1700, validation accuracy 97.58%
# [2016-09-01 22:07:03] step 1800, validation accuracy 97.46%
# [2016-09-01 22:07:05] step 1900, validation accuracy 97.70%
# [2016-09-01 22:07:08] step 2000, validation accuracy 97.58%
# [2016-09-01 22:09:22] step 6700, validation accuracy 98.88%
# [2016-09-01 22:09:25] step 6800, validation accuracy 98.84%
# [2016-09-01 22:09:28] step 6900, validation accuracy 99.02%
# [2016-09-01 22:09:30] step 7000, validation accuracy 98.84%
# [2016-09-01 22:09:33] step 7100, validation accuracy 98.86%
# [2016-09-01 22:09:36] step 7200, validation accuracy 98.88%
# [2016-09-01 22:09:39] step 7300, validation accuracy 98.84%
# [2016-09-01 22:09:42] step 7400, validation accuracy 99.10%
# [2016-09-01 22:09:45] step 7500, validation accuracy 98.98%
# [2016-09-01 22:09:48] step 7600, validation accuracy 98.88%
# [2016-09-01 22:09:50] step 7700, validation accuracy 99.02%
# [2016-09-01 22:09:53] step 7800, validation accuracy 99.00%
# [2016-09-01 22:09:56] step 7900, validation accuracy 99.04%
# [2016-09-01 22:09:59] step 8000, validation accuracy 98.98%
# [2016-09-01 22:10:02] step 8100, validation accuracy 99.00%
# [2016-09-01 22:10:05] step 8200, validation accuracy 98.98%
# [2016-09-01 22:10:07] step 8300, validation accuracy 98.98%
# [2016-09-01 22:10:10] step 8400, validation accuracy 99.04%
# [2016-09-01 22:10:13] step 8500, validation accuracy 98.96%
# [2016-09-01 22:10:16] step 8600, validation accuracy 99.00%
# [2016-09-01 22:10:19] step 8700, validation accuracy 99.02%
# [2016-09-01 22:10:22] step 8800, validation accuracy 99.04%
# [2016-09-01 22:10:25] step 8900, validation accuracy 99.02%
# [2016-09-01 22:10:27] step 9000, validation accuracy 98.96%
# [2016-09-01 22:10:30] step 9100, validation accuracy 99.04%
# [2016-09-01 22:10:33] step 9200, validation accuracy 99.08%
# [2016-09-01 22:10:36] step 9300, validation accuracy 99.10%
# [2016-09-01 22:10:39] step 9400, validation accuracy 99.10%
# [2016-09-01 22:10:42] step 9500, validation accuracy 98.96%
# [2016-09-01 22:10:44] step 9600, validation accuracy 99.02%
# [2016-09-01 22:10:47] step 9700, validation accuracy 99.04%
# [2016-09-01 22:10:50] step 9800, validation accuracy 98.96%
# [2016-09-01 22:10:53] step 9900, validation accuracy 99.08%
# [2016-09-01 22:10:56] step 10000, validation accuracy 98.98%
# [2016-09-01 22:10:59] step 10100, validation accuracy 99.00%
# [2016-09-01 22:11:02] step 10200, validation accuracy 99.12%
# [2016-09-01 22:11:04] step 10300, validation accuracy 99.00%
# [2016-09-01 22:11:07] step 10400, validation accuracy 98.88%
# [2016-09-01 22:11:10] step 10500, validation accuracy 98.90%
# [2016-09-01 22:11:13] step 10600, validation accuracy 98.98%
# [2016-09-01 22:11:16] step 10700, validation accuracy 99.04%
# [2016-09-01 22:11:19] step 10800, validation accuracy 98.92%
# [2016-09-01 22:11:21] step 10900, validation accuracy 99.06%
# [2016-09-01 22:11:24] step 11000, validation accuracy 99.06%
# [2016-09-01 22:11:27] step 11100, validation accuracy 98.96%
# [2016-09-01 22:11:30] step 11200, validation accuracy 99.10%
# [2016-09-01 22:13:41] step 15800, validation accuracy 99.14%
# [2016-09-01 22:13:44] step 15900, validation accuracy 99.18%
# [2016-09-01 22:13:47] step 16000, validation accuracy 99.08%
# [2016-09-01 22:13:50] step 16100, validation accuracy 99.16%
# [2016-09-01 22:13:52] step 16200, validation accuracy 99.28%
# [2016-09-01 22:13:55] step 16300, validation accuracy 99.16%
# [2016-09-01 22:13:58] step 16400, validation accuracy 99.18%
# [2016-09-01 22:14:01] step 16500, validation accuracy 99.20%
# [2016-09-01 22:14:04] step 16600, validation accuracy 99.24%
# [2016-09-01 22:14:07] step 16700, validation accuracy 99.14%
# [2016-09-01 22:14:10] step 16800, validation accuracy 99.24%
# [2016-09-01 22:14:12] step 16900, validation accuracy 99.24%
# [2016-09-01 22:14:15] step 17000, validation accuracy 99.06%
# [2016-09-01 22:14:18] step 17100, validation accuracy 99.10%
# [2016-09-01 22:14:21] step 17200, validation accuracy 99.18%
# [2016-09-01 22:14:24] step 17300, validation accuracy 99.24%
# [2016-09-01 22:14:27] step 17400, validation accuracy 99.18%
# [2016-09-01 22:14:29] step 17500, validation accuracy 99.20%
# [2016-09-01 22:14:32] step 17600, validation accuracy 99.28%
# [2016-09-01 22:14:35] step 17700, validation accuracy 99.18%
# [2016-09-01 22:14:38] step 17800, validation accuracy 99.30%
# [2016-09-01 22:14:41] step 17900, validation accuracy 99.16%
# [2016-09-01 22:14:44] step 18000, validation accuracy 99.22%
# [2016-09-01 22:14:46] step 18100, validation accuracy 99.28%
# [2016-09-01 22:14:49] step 18200, validation accuracy 99.20%
# [2016-09-01 22:14:52] step 18300, validation accuracy 99.24%
# [2016-09-01 22:14:55] step 18400, validation accuracy 99.22%
# [2016-09-01 22:14:58] step 18500, validation accuracy 99.22%
# [2016-09-01 22:15:01] step 18600, validation accuracy 99.24%
# [2016-09-01 22:15:04] step 18700, validation accuracy 99.24%
# [2016-09-01 22:15:06] step 18800, validation accuracy 99.18%
# [2016-09-01 22:15:09] step 18900, validation accuracy 99.30%
# [2016-09-01 22:15:12] step 19000, validation accuracy 99.32%
# [2016-09-01 22:15:15] step 19100, validation accuracy 99.20%
# [2016-09-01 22:15:18] step 19200, validation accuracy 99.26%
# [2016-09-01 22:15:21] step 19300, validation accuracy 99.30%
# [2016-09-01 22:15:23] step 19400, validation accuracy 99.24%
# [2016-09-01 22:15:26] step 19500, validation accuracy 99.36%
# [2016-09-01 22:15:29] step 19600, validation accuracy 99.26%
# [2016-09-01 22:15:32] step 19700, validation accuracy 99.22%
# [2016-09-01 22:15:35] step 19800, validation accuracy 99.04%
# [2016-09-01 22:15:38] step 19900, validation accuracy 99.28%
# [2016-09-01 22:15:41] step 20000, validation accuracy 99.26%

# %%
# Run inference and get accuracy.
print("test accuracy %g"%accuracy.eval(feed_dict={
    x: dataset.test.images, y_: dataset.test.labels, keep_prob: 1.0}))
# Out:
# test accuracy 0.9919
